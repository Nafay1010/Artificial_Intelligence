# %%
from PIL import Image
import glob
image_list = []
for filename in glob.glob(r'C:\\Users\\LENOVO\\Downloads\\FAST PWR\\VSCODE\\Python\\Tensor_Flow\\flowers\\daisy/*.jpg'):  # assuming gif
    im = Image.open(filename)
    image_list.append(im)

# %%
image_list[4]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x250 at 0x1D6EB926140>

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import cv2
import seaborn as sns
import random
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import pathlib

# %%
image_size = (100, 100)  # 100X100 image size
batch_size = 26  # 26 alphabets so, each batch size is 26

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "flowers",
    validation_split=0.2,
    subset="training",
    seed=1500,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 4317 files belonging to 5 classes.
# Using 3454 files for training.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
    plt.imshow(images[1].numpy().astype("uint8"))
